# %% [markdown]
# <a href="https://colab.research.google.com/github/Mallesh06/Smart-Rain-Detection-Automated-Irrigation/blob/main/smart_rain_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 🌧️ Smart Rain Detection – Basic Demo
# Author: Pawan Mallesham
# Internship: Automotive Object Detection (AICTE × Edunet × Shell Skills4Future)

from transformers import AutoImageProcessor, AutoModelForImageClassification
from PIL import Image
import torch

# -------- 1️⃣  Load a pre-trained weather classification model ------------
# (This model can classify images as sunny, rainy, cloudy, snowy, etc.)
# Changed model name to a publicly available model
model_name = "cippa/weather_classification"

print(f"Loading model: {model_name} ...")
processor = AutoImageProcessor.from_pretrained(model_name)
model = AutoModelForImageClassification.from_pretrained(model_name)
print("Model loaded successfully ✅\n")

# -------- 2️⃣  Load an image ------------
# Replace this path with your own image (rainy or clear scene)
image_path = "/content/rain_sample.jpg"

try:
    image = Image.open(image_path)
except FileNotFoundError:
    raise SystemExit(f"❌ Could not find image at {image_path}. Place an image there first.")

# -------- 3️⃣  Preprocess and run inference ------------
inputs = processor(images=image, return_tensors="pt")
outputs = model(**inputs)
predictions = torch.nn.functional.softmax(outputs.logits, dim=-1)
predicted_class_idx = predictions.argmax(-1).item()
label = model.config.id2label[predicted_class_idx]
confidence = predictions[0][predicted_class_idx].item() * 100

print(f"🖼️  Image: {image_path}")
print(f"🌦️  Predicted weather: {label} ({confidence:.2f}% confidence)\n")

# -------- 4️⃣  Simulate motor control logic ------------
if "rain" in label.lower():
    print("💧 Rain detected → Turning OFF irrigation motor.")
else:
    print("☀️  No rain detected → Motor remains ON.")

# -------- 5️⃣  Done! ------------
print("\n✅ Process completed.")
# Out:
# Loading model: cippa/weather_classification ...
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_http.py in hf_raise_for_status(response, endpoint_name)
#     401     try:
# --> 402         response.raise_for_status()
#     403     except HTTPError as e:
#
# /usr/local/lib/python3.12/dist-packages/requests/models.py in raise_for_status(self)
#    1025         if http_error_msg:
# -> 1026             raise HTTPError(http_error_msg, response=self)
#    1027
#
# HTTPError: 401 Client Error: Unauthorized for url: https://huggingface.co/cippa/weather_classification/resolve/main/preprocessor_config.json
#
# The above exception was the direct cause of the following exception:
#
# RepositoryNotFoundError                   Traceback (most recent call last)
# ...

# %% [markdown]
# # New section
